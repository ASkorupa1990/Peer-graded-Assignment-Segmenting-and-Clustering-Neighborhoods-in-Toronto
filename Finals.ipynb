# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import json # library to handle JSON files

# Matplotlib and associated plotting modules
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# Use the inline backend to generate the plots within the browser
# %matplotlib inline 

import seaborn as sns
sns.set_style("darkgrid")

#If Need to re-download some files saved earlier//or scrape again. 
import requests # library to handle requests
import lxml.html as lh
import bs4 as bs
import urllib.request

from IPython.display import HTML
import base64

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Restore dataframe collection : 
sg_food_csv  = r'https://raw.githubusercontent.com/crismag/Coursera_Capstone/master/saved_data/singapore_food_venues.600Scores.Category.csv'
venue_columns = ['Town','Town Latitude','Town Longitude','VenueID','VenueName','score','category','catID','latitude','longitude']
singapore_food_venues      = pd.read_csv(sg_food_csv, usecols=venue_columns, encoding = "ISO-8859-1")

# Eliminate possible venue duplicates.
singapore_town_venues = singapore_food_venues[venue_columns]
# Drop rows with score == 0
singapore_town_venues = singapore_town_venues[singapore_town_venues.score > 0.0]
# Drop rows with missing elements
singapore_town_venues = singapore_town_venues.dropna(axis='columns')

singapore_food_venues.head()
# Out:
#          Town  Town Latitude  Town Longitude                   VenueID  \
# 0  ANG MO KIO       1.369972      103.849588  538ef3d5498e088ff4b1e8ba
# 1  ANG MO KIO       1.369972      103.849588  4d397d4a1fc36dcbe8815bf5
# 2  ANG MO KIO       1.369972      103.849588  50138eaee4b05d9dc80ae5b0
# 3  ANG MO KIO       1.369972      103.849588  4ba1b90df964a52094c937e3
# 4  ANG MO KIO       1.369972      103.849588  5be2d3831af8520039a38da2
#
#                             VenueName  score          category  \
# 0                    Koi Café Express    0.0  Bubble Tea Shops
# 1                         BBQ Express    0.0        BBQ Joints
# 2  Hong Kong Sheng Kee Dessert ??????    5.8     Dessert Shops
# 3        Shihlin Taiwan Street Snacks    0.0      Snack Places
# 4                     Malaysia Boleh!    7.5       Food Courts
#
#                       catID  latitude   longitude
# 0  52e81612bcbc57f1066b7a0c  1.369342  103.849820
# 1  4bf58dd8d48988d1df931735  1.369239  103.849215
# 2  4bf58dd8d48988d1d0941735  1.369473  103.849241
# 3  4bf58dd8d48988d1c7941735  1.369309  103.849261
# 4  4bf58dd8d48988d120951735  1.369669  103.848900

# %%
venue_counts = singapore_town_venues.groupby('Town').count()
venue_counts
# Out:
#                  Town Latitude  Town Longitude  VenueID  VenueName  score  \
# Town
# ANG MO KIO                  34              34       34         34     34
# BEDOK                       29              29       29         29     29
# BISHAN                      36              36       36         36     36
# BUKIT BATOK                 22              22       22         22     22
# BUKIT MERAH                  9               9        9          9      9
# BUKIT PANJANG               15              15       15         15     15
# CENTRAL                     46              46       46         46     46
# CHOA CHU KANG               27              27       27         27     27
# CLEMENTI                    34              34       34         34     34
# GEYLANG                     25              25       25         25     25
# HOUGANG                     26              26       26         26     26
# JURONG EAST                 39              39       39         39     39
# JURONG WEST                 31              31       31         31     31
# KALLANG/WHAMPOA             15              15       15         15     15
# MARINE PARADE               21              21       21         21     21
# PASIR RIS                   17              17       17         17     17
# PUNGGOL                     25              25       25         25     25
# QUEENSTOWN                   8               8        8          8      8
# SEMBAWANG                   18              18       18         18     18
# SENGKANG                    17              17       17         17     17
# SERANGOON                   42              42       42         42     42
# TAMPINES                    25              25       25         25     25
# TOA PAYOH                   34              34       34         34     34
# WOODLANDS                   31              31       31         31     31
# YISHUN                      18              18       18         18     18
#
#                  category  catID  latitude  longitude
# Town
# ANG MO KIO             34     34        34         34
# BEDOK                  29     29        29         29
# BISHAN                 36     36        36         36
# BUKIT BATOK            22     22        22         22
# BUKIT MERAH             9      9         9          9
# BUKIT PANJANG          15     15        15         15
# CENTRAL                46     46        46         46
# CHOA CHU KANG          27     27        27         27
# CLEMENTI               34     34        34         34
# GEYLANG                25     25        25         25
# HOUGANG                26     26        26         26
# JURONG EAST            39     39        39         39
# JURONG WEST            31     31        31         31
# KALLANG/WHAMPOA        15     15        15         15
# MARINE PARADE          21     21        21         21
# PASIR RIS              17     17        17         17
# PUNGGOL                25     25        25         25
# QUEENSTOWN              8      8         8          8
# SEMBAWANG              18     18        18         18
# SENGKANG               17     17        17         17
# SERANGOON              42     42        42         42
# TAMPINES               25     25        25         25
# TOA PAYOH              34     34        34         34
# WOODLANDS              31     31        31         31
# YISHUN                 18     18        18         18

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
singapore_town_venues.plot.scatter('score', 'Town Latitude', figsize=(10,6))
#singapore_town_venues.plot.scatter('score', 'latitude', figsize=(10,6))

plt.xlabel('Score')
plt.ylabel('Town Latitude')
plt.title('Scatter Plot of Top venues in "Town Latitude" and Score', loc='center', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Top venues in "Town Latitude" and Score')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax0 = sns.barplot(data = venue_counts.reset_index(), x = 'score', y = 'Town')
ax0.set_title("Top Town Venue Recommendation Counts")
ax0.set_xlabel('Total Scores')
plt.show()

# %%
top_10_venue = singapore_town_venues.groupby('category')['VenueName'].count().sort_values(ascending=False)[:10].reset_index()
labels = top_10_venue['category']
sizes  = top_10_venue['VenueName']
explode = [.1] * 10
# Plot
plt.title("Top 10 Recommended Venue in Food Category Type")
ax1 = plt.pie(sizes, explode=explode, labels=labels, shadow=True, startangle=90)
plt.axis('equal')
plt.show()
top_10_venue
# Out:
#                 category  VenueName
# 0            Food Courts         92
# 1           Coffee Shops         62
# 2  Fast Food Restaurants         61
# 3    Chinese Restaurants         58
# 4                  Cafés         35
# 5   Japanese Restaurants         34
# 6      Asian Restaurants         22
# 7          Noodle Houses         20
# 8       Thai Restaurants         19
# 9      Sushi Restaurants         16

# %%
# Top 20 venues with highest given score rating
top_20_scorer = singapore_town_venues.groupby(['Town','category'])['score'].mean().sort_values(ascending=False)[:20].reset_index()
top_20_scorer
# Out:
#              Town              category  score
# 0   MARINE PARADE           Food Courts   8.70
# 1         CENTRAL     Asian Restaurants   8.50
# 2         CENTRAL   Seafood Restaurants   8.35
# 3          YISHUN         Noodle Houses   8.30
# 4         CENTRAL      Udon Restaurants   8.30
# 5         GEYLANG            BBQ Joints   8.30
# 6         CENTRAL             Breweries   8.20
# 7         CENTRAL  Dumpling Restaurants   8.10
# 8          YISHUN      Bubble Tea Shops   8.10
# 9          YISHUN   Chinese Restaurants   8.00
# 10          BEDOK   Chinese Restaurants   8.00
# 11    JURONG WEST          Wings Joints   8.00
# 12        CENTRAL      Bubble Tea Shops   8.00
# 13        HOUGANG      Thai Restaurants   7.90
# 14    JURONG EAST    Hotpot Restaurants   7.90
# 15  BUKIT PANJANG                 Cafés   7.90
# 16        CENTRAL               Bistros   7.90
# 17  BUKIT PANJANG      Thai Restaurants   7.85
# 18        GEYLANG                 Cafés   7.80
# 19       TAMPINES  Fried Chicken Joints   7.80

# %%
sg_top_clusters = r'https://raw.githubusercontent.com/crismag/Coursera_Capstone/master/saved_data/sg_top_clusters.csv'
sg_town_clusters = pd.read_csv(sg_top_clusters)
sg_town_clusters.head()
# Out:
#           Town  median_rent  Latitude   Longitude  Cluster Labels  \
# 0   ANG MO KIO  2033.333333  1.369972  103.849588               1
# 1        BEDOK  2087.500000  1.324011  103.930172               3
# 2       BISHAN  2233.333333  1.351042  103.849930               3
# 3  BUKIT BATOK  1962.500000  1.348506  103.749222               1
# 4  BUKIT MERAH  2162.500000  1.289642  103.816798               2
#
#   1st Most Common Venue  2nd Most Common Venue  3rd Most Common Venue  \
# 0           Food Courts  Fast Food Restaurants          Dessert Shops
# 1          Coffee Shops            Food Courts      Sushi Restaurants
# 2          Coffee Shops   Japanese Restaurants    Chinese Restaurants
# 3           Food Courts           Coffee Shops  Fast Food Restaurants
# 4   Chinese Restaurants           Coffee Shops            Food Courts
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0   Japanese Restaurants      Sushi Restaurants                 Cafés
# 1   Japanese Restaurants  Fast Food Restaurants          Wings Joints
# 2  Fast Food Restaurants            Food Courts                 Cafés
# 3    Chinese Restaurants      Asian Restaurants      Thai Restaurants
# 4                Bistros                  Cafés   Dongbei Restaurants
#
#       7th Most Common Venue  8th Most Common Venue   9th Most Common Venue  \
# 0         Ramen Restaurants  Hong Kong Restaurants       Halal Restaurants
# 1      Fried Chicken Joints     Indian Restaurants         Ice Cream Shops
# 2          Bubble Tea Shops   American Restaurants  Portuguese Restaurants
# 3              Pizza Places        Ice Cream Shops    Japanese Restaurants
# 4  Comfort Food Restaurants          Dessert Shops     Dim Sum Restaurants
#
#   10th Most Common Venue
# 0    Miscellaneous Shops
# 1     Hotpot Restaurants
# 2   Dumpling Restaurants
# 3        Sandwich Places
# 4                 Diners

# %%
rent_cluster_df = sg_town_clusters[['Town','median_rent','Cluster Labels']].copy()
rent_cluster_df
# Out:
#                Town  median_rent  Cluster Labels
# 0        ANG MO KIO  2033.333333               1
# 1             BEDOK  2087.500000               3
# 2            BISHAN  2233.333333               3
# 3       BUKIT BATOK  1962.500000               1
# 4       BUKIT MERAH  2162.500000               2
# 5     BUKIT PANJANG  1737.500000               4
# 6           CENTRAL  2450.000000               3
# 7     CHOA CHU KANG  1933.333333               1
# 8          CLEMENTI  2263.333333               1
# 9           GEYLANG  2166.666667               4
# 10          HOUGANG  1962.500000               1
# 11      JURONG EAST  2150.000000               3
# 12      JURONG WEST  1975.000000               3
# 13  KALLANG/WHAMPOA  2300.000000               0
# 14    MARINE PARADE  1950.000000               0
# 15        PASIR RIS  2066.666667               1
# 16          PUNGGOL  1825.000000               1
# 17       QUEENSTOWN  2162.500000               4
# 18        SEMBAWANG  1883.333333               1
# 19         SENGKANG  1900.000000               3
# 20        SERANGOON  2187.500000               3
# 21         TAMPINES  2075.000000               1
# 22        TOA PAYOH  2210.000000               3
# 23        WOODLANDS  1762.500000               3
# 24           YISHUN  1900.000000               1
